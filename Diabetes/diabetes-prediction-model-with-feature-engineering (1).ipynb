# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import warnings
warnings.filterwarnings("ignore")

import gc

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.isotonic import IsotonicRegression
from sklearn.feature_selection import SelectFromModel

import xgboost as xgb
import lightgbm as lgb
import catboost as cb

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/playground-series-s5e12/sample_submission.csv
# /kaggle/input/playground-series-s5e12/train.csv
# /kaggle/input/playground-series-s5e12/test.csv

# %%
INPUT_DIR = "/kaggle/input/playground-series-s5e12"

TARGET = "diagnosed_diabetes"
ID_COL = "id"  # name of the ID column in train/test

# Competition data
train = pd.read_csv(f"{INPUT_DIR}/train.csv")
test = pd.read_csv(f"{INPUT_DIR}/test.csv")
submission = pd.read_csv(f"{INPUT_DIR}/sample_submission.csv")

print("Shapes:")
print(f"  train: {train.shape}")
print(f"  test: {test.shape}")
print(f"Target column: {TARGET}")
# Out:
# Shapes:
#   train: (700000, 26)
#   test: (300000, 25)
# Target column: diagnosed_diabetes

# %% [markdown]
# ## Feature Engineering

# %%
# All columns except ID and target
base_cols = [c for c in train.columns if c not in [ID_COL, TARGET]]

print(f"Number of base features: {len(base_cols)}")
print("Example base features:", base_cols[:10])
# Out:
# Number of base features: 24
# Example base features: ['age', 'alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'diet_score', 'sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi', 'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp']

# %%
# Clinical feature engineering


def add_clinical_features(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add a few simple, clinically meaningful features:
    - bmi_cat: BMI category (underweight, normal, overweight, obese)
    - bp_cat: blood pressure category based on systolic/diastolic BP
    - non_hdl: non-HDL cholesterol (total - HDL)
    """
    df = df.copy()
    
    # 1) BMI categories: 0=underweight, 1=normal, 2=overweight, 3=obese
    if "bmi" in df.columns:
        df["bmi_cat"] = pd.cut(
            df["bmi"],
            bins=[0, 18.5, 25, 30, 999],
            labels=[0, 1, 2, 3],
            include_lowest=True
        ).astype("int64")
    
    # 2) Blood pressure categories: 0=normal, 1=elevated/pre-hypertension, 2=high
    if {"systolic_bp", "diastolic_bp"}.issubset(df.columns):
        df["bp_cat"] = 0
        df.loc[
            (df["systolic_bp"] >= 140) | (df["diastolic_bp"] >= 90),
            "bp_cat"
        ] = 2
        df.loc[
            (
                (df["systolic_bp"] >= 120) & (df["systolic_bp"] < 140)
            ) | (
                (df["diastolic_bp"] >= 80) & (df["diastolic_bp"] < 90)
            ),
            "bp_cat"
        ] = 1
        df["bp_cat"] = df["bp_cat"].astype("int64")
    
    # 3) Non-HDL cholesterol: total cholesterol - HDL
    if {"cholesterol_total", "hdl_cholesterol"}.issubset(df.columns):
        df["non_hdl"] = df["cholesterol_total"] - df["hdl_cholesterol"]
    
    return df

# Apply to train and test
train_fe = add_clinical_features(train)
test_fe = add_clinical_features(test)

print("Train columns after feature engineering:", len(train_fe.columns))
print("Test columns after feature engineering:", len(test_fe.columns))
# Out:
# Train columns after feature engineering: 29
# Test columns after feature engineering: 28

# %%
# Final feature matrices

extra_features = ["bmi_cat", "bp_cat", "non_hdl"]

# Some of these might not exist if the source columns were missing, so keep only those that are present
extra_features = [f for f in extra_features if f in train_fe.columns]

features = base_cols + extra_features

print(f"Total number of features used: {len(features)}")

X = train_fe[features].copy()
y = train_fe[TARGET].copy()
X_test = test_fe[features].copy()

print("X shape:", X.shape)
print("X_test shape:", X_test.shape)
# Out:
# Total number of features used: 27
# X shape: (700000, 27)
# X_test shape: (300000, 27)

# %%
# Handling missing values

# Fill numeric NaNs with median of training data
num_cols = X.select_dtypes(include=[np.number]).columns.tolist()

for col in num_cols:
    median_val = X[col].median()
    X[col] = X[col].fillna(median_val)
    X_test[col] = X_test[col].fillna(median_val)

# %%
# Label encode only object (string) columns
cat_cols = X.select_dtypes(include=["object"]).columns.tolist()
print("Categorical (object) columns:", cat_cols)

for col in cat_cols:
    le = LabelEncoder()
    # fit on train
    X[col] = le.fit_transform(X[col].astype(str))
    # transform test with same mapping
    X_test[col] = le.transform(X_test[col].astype(str))
# Out:
# Categorical (object) columns: ['gender', 'ethnicity', 'education_level', 'income_level', 'smoking_status', 'employment_status']

# %% [markdown]
# ## Model development

# %%
# Cross-validated XGBoost model

n_splits = 5  # you can change to 10 if your runtime is OK
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

oof_pred = np.zeros(len(X))        # out-of-fold predictions for train
test_pred = np.zeros(len(X_test))  # averaged predictions for test

fold_auc_scores = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), start=1):
    print(f"\n===== Fold {fold}/{n_splits} =====")
    
    X_trn, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_trn, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    model = xgb.XGBClassifier(
        n_estimators=2000,
        learning_rate=0.02,
        max_depth=4,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=2.0,       # L1 regularization
        reg_lambda=3.0,      # L2 regularization
        objective="binary:logistic",
        eval_metric="auc",
        random_state=42,
        n_jobs=-1            # use all CPU cores
    )
    
    model.fit(
        X_trn, y_trn,
        eval_set=[(X_trn, y_trn), (X_val, y_val)],
        verbose=100,
        early_stopping_rounds=200
    )
    
    # Best iteration chosen by early stopping
    best_iter = model.best_iteration
    print(f"Best iteration: {best_iter}")
    
    # OOF predictions for validation fold
    val_proba = model.predict_proba(X_val)[:, 1]
    oof_pred[val_idx] = val_proba
    
    # AUC on this fold
    fold_auc = roc_auc_score(y_val, val_proba)
    fold_auc_scores.append(fold_auc)
    print(f"Fold {fold} AUC: {fold_auc:.6f}")
    
    # Test predictions (average over folds)
    test_proba = model.predict_proba(X_test)[:, 1]
    test_pred += test_proba / n_splits  # accumulate average

# Overall CV AUC using all OOF predictions
cv_auc = roc_auc_score(y, oof_pred)
print("\n===== Cross-validation summary =====")
print("Fold AUCs:", [round(s, 6) for s in fold_auc_scores])
print(f"Mean AUC: {np.mean(fold_auc_scores):.6f}  |  Std: {np.std(fold_auc_scores):.6f}")
print(f"OOF CV AUC (all folds combined): {cv_auc:.6f}")
# Out:
# ===== Fold 1/5 =====
# [0]	validation_0-auc:0.67134	validation_1-auc:0.67229
# [100]	validation_0-auc:0.69676	validation_1-auc:0.69663
# [200]	validation_0-auc:0.70413	validation_1-auc:0.70348
# [300]	validation_0-auc:0.70895	validation_1-auc:0.70791
# [400]	validation_0-auc:0.71185	validation_1-auc:0.71051
# [500]	validation_0-auc:0.71475	validation_1-auc:0.71312
# [600]	validation_0-auc:0.71708	validation_1-auc:0.71513
# [700]	validation_0-auc:0.71911	validation_1-auc:0.71680
# [800]	validation_0-auc:0.72114	validation_1-auc:0.71858
# [900]	validation_0-auc:0.72267	validation_1-auc:0.71980
# [1000]	validation_0-auc:0.72382	validation_1-auc:0.72056
# [1100]	validation_0-auc:0.72505	validation_1-auc:0.72147
# [1200]	validation_0-auc:0.72611	validation_1-auc:0.72225
# [1300]	validation_0-auc:0.72704	validation_1-auc:0.72288
# [1400]	validation_0-auc:0.72789	validation_1-auc:0.72341
# [1500]	validation_0-auc:0.72860	validation_1-auc:0.72377
# [1600]	validation_0-auc:0.72939	validation_1-auc:0.72422
# [1700]	validation_0-auc:0.72997	validation_1-auc:0.72445
# [1800]	validation_0-auc:0.73057	validation_1-auc:0.72473
# [1900]	validation_0-auc:0.73115	validation_1-auc:0.72498
# [1999]	validation_0-auc:0.73168	validation_1-auc:0.72517
# Best iteration: 1998
# Fold 1 AUC: 0.725170
#
# ===== Fold 2/5 =====
# [0]	validation_0-auc:0.67240	validation_1-auc:0.67006
# [100]	validation_0-auc:0.69719	validation_1-auc:0.69530
# [200]	validation_0-auc:0.70469	validation_1-auc:0.70253
# [300]	validation_0-auc:0.70908	validation_1-auc:0.70635
# [400]	validation_0-auc:0.71171	validation_1-auc:0.70854
# [500]	validation_0-auc:0.71460	validation_1-auc:0.71104
# [600]	validation_0-auc:0.71720	validation_1-auc:0.71326
# [700]	validation_0-auc:0.71954	validation_1-auc:0.71516
# [800]	validation_0-auc:0.72142	validation_1-auc:0.71665
# [900]	validation_0-auc:0.72293	validation_1-auc:0.71781
# [1000]	validation_0-auc:0.72405	validation_1-auc:0.71858
# [1100]	validation_0-auc:0.72523	validation_1-auc:0.71939
# [1200]	validation_0-auc:0.72628	validation_1-auc:0.72010
# [1300]	validation_0-auc:0.72723	validation_1-auc:0.72071
# [1400]	validation_0-auc:0.72803	validation_1-auc:0.72119
# [1500]	validation_0-auc:0.72883	validation_1-auc:0.72164
# [1600]	validation_0-auc:0.72959	validation_1-auc:0.72208
# [1700]	validation_0-auc:0.73025	validation_1-auc:0.72242
# [1800]	validation_0-auc:0.73087	validation_1-auc:0.72273
# [1900]	validation_0-auc:0.73145	validation_1-auc:0.72296
# [1999]	validation_0-auc:0.73209	validation_1-auc:0.72330
# Best iteration: 1999
# Fold 2 AUC: 0.723295
#
# ===== Fold 3/5 =====
# [0]	validation_0-auc:0.67330	validation_1-auc:0.67300
# [100]	validation_0-auc:0.69704	validation_1-auc:0.69607
# [200]	validation_0-auc:0.70452	validation_1-auc:0.70276
# [300]	validation_0-auc:0.70914	validation_1-auc:0.70683
# [400]	validation_0-auc:0.71195	validation_1-auc:0.70931
# [500]	validation_0-auc:0.71450	validation_1-auc:0.71152
# [600]	validation_0-auc:0.71731	validation_1-auc:0.71403
# [700]	validation_0-auc:0.71919	validation_1-auc:0.71560
# [800]	validation_0-auc:0.72119	validation_1-auc:0.71730
# [900]	validation_0-auc:0.72265	validation_1-auc:0.71844
# [1000]	validation_0-auc:0.72385	validation_1-auc:0.71932
# [1100]	validation_0-auc:0.72498	validation_1-auc:0.72012
# [1200]	validation_0-auc:0.72599	validation_1-auc:0.72079
# [1300]	validation_0-auc:0.72698	validation_1-auc:0.72149
# [1400]	validation_0-auc:0.72781	validation_1-auc:0.72200
# [1500]	validation_0-auc:0.72862	validation_1-auc:0.72250
# [1600]	validation_0-auc:0.72935	validation_1-auc:0.72291
# [1700]	validation_0-auc:0.72996	validation_1-auc:0.72322
# [1800]	validation_0-auc:0.73053	validation_1-auc:0.72347
# [1900]	validation_0-auc:0.73112	validation_1-auc:0.72375
# [1999]	validation_0-auc:0.73167	validation_1-auc:0.72399
# Best iteration: 1999
# Fold 3 AUC: 0.723988
#
# ===== Fold 4/5 =====
# [0]	validation_0-auc:0.67225	validation_1-auc:0.67133
# [100]	validation_0-auc:0.69727	validation_1-auc:0.69631
# [200]	validation_0-auc:0.70486	validation_1-auc:0.70386
# [300]	validation_0-auc:0.70907	validation_1-auc:0.70784
# [400]	validation_0-auc:0.71193	validation_1-auc:0.71044
# [500]	validation_0-auc:0.71442	validation_1-auc:0.71263
# [600]	validation_0-auc:0.71711	validation_1-auc:0.71506
# [700]	validation_0-auc:0.71907	validation_1-auc:0.71676
# [800]	validation_0-auc:0.72100	validation_1-auc:0.71843
# [900]	validation_0-auc:0.72254	validation_1-auc:0.71968
# [1000]	validation_0-auc:0.72383	validation_1-auc:0.72068
# [1100]	validation_0-auc:0.72501	validation_1-auc:0.72157
# [1200]	validation_0-auc:0.72598	validation_1-auc:0.72223
# [1300]	validation_0-auc:0.72710	validation_1-auc:0.72310
# [1400]	validation_0-auc:0.72794	validation_1-auc:0.72367
# [1500]	validation_0-auc:0.72867	validation_1-auc:0.72410
# [1600]	validation_0-auc:0.72941	validation_1-auc:0.72449
# [1700]	validation_0-auc:0.72999	validation_1-auc:0.72478
# [1800]	validation_0-auc:0.73057	validation_1-auc:0.72504
# [1900]	validation_0-auc:0.73113	validation_1-auc:0.72530
# [1999]	validation_0-auc:0.73175	validation_1-auc:0.72563
# Best iteration: 1999
# Fold 4 AUC: 0.725629
#
# ===== Fold 5/5 =====
# [0]	validation_0-auc:0.67181	validation_1-auc:0.67233
# [100]	validation_0-auc:0.69687	validation_1-auc:0.69636
# [200]	validation_0-auc:0.70410	validation_1-auc:0.70337
# [300]	validation_0-auc:0.70820	validation_1-auc:0.70724
# [400]	validation_0-auc:0.71141	validation_1-auc:0.71010
# [500]	validation_0-auc:0.71401	validation_1-auc:0.71236
# [600]	validation_0-auc:0.71643	validation_1-auc:0.71438
# [700]	validation_0-auc:0.71868	validation_1-auc:0.71632
# [800]	validation_0-auc:0.72056	validation_1-auc:0.71793
# [900]	validation_0-auc:0.72217	validation_1-auc:0.71923
# [1000]	validation_0-auc:0.72346	validation_1-auc:0.72017
# [1100]	validation_0-auc:0.72461	validation_1-auc:0.72096
# [1200]	validation_0-auc:0.72567	validation_1-auc:0.72172
# [1300]	validation_0-auc:0.72663	validation_1-auc:0.72234
# [1400]	validation_0-auc:0.72742	validation_1-auc:0.72278
# [1500]	validation_0-auc:0.72820	validation_1-auc:0.72324
# [1600]	validation_0-auc:0.72891	validation_1-auc:0.72365
# [1700]	validation_0-auc:0.72962	validation_1-auc:0.72403
# [1800]	validation_0-auc:0.73024	validation_1-auc:0.72433
# [1900]	validation_0-auc:0.73085	validation_1-auc:0.72461
# [1999]	validation_0-auc:0.73137	validation_1-auc:0.72483
# Best iteration: 1998
# Fold 5 AUC: 0.724829
#
# ===== Cross-validation summary =====
# Fold AUCs: [0.72517, 0.723295, 0.723988, 0.725629, 0.724829]
# Mean AUC: 0.724582  |  Std: 0.000838
# OOF CV AUC (all folds combined): 0.724576

# %%
# submission file

# Attach the predictions to the submission template
submission[TARGET] = test_pred

# Name your output file (you can change this name)
OUTPUT_PATH = "submission_xgb_cv.csv"

# Save to CSV
submission.to_csv(OUTPUT_PATH, index=False)

print(f"Submission file saved as: {OUTPUT_PATH}")
print(f"Mean predicted probability: {submission[TARGET].mean():.5f}")
submission.head()
# Out:
# Submission file saved as: submission_xgb_cv.csv
# Mean predicted probability: 0.60198
#        id  diagnosed_diabetes
# 0  700000            0.500116
# 1  700001            0.681262
# 2  700002            0.763460
# 3  700003            0.423186
# 4  700004            0.917896

# %% [markdown]
# ## Feature Selection

# %%
# Feature selection + CV model on selected features

from sklearn.feature_selection import SelectFromModel

# 8.1 Train a model on all data to get feature importance
fs_model = xgb.XGBClassifier(
    n_estimators=1000,
    learning_rate=0.02,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=2.0,
    reg_lambda=3.0,
    objective="binary:logistic",
    eval_metric="auc",
    random_state=42,
    n_jobs=-1
)

fs_model.fit(X, y)

# 8.2 Use SelectFromModel to keep only important features
selector = SelectFromModel(
    fs_model,
    threshold="median",   # keep features with importance above the median
    prefit=True           # model is already fitted
)

X_fs = selector.transform(X)
X_test_fs = selector.transform(X_test)

# Get the names of selected features
feature_mask = selector.get_support()
selected_features = [f for f, keep in zip(features, feature_mask) if keep]

print(f"Original number of features: {len(features)}")
print(f"Selected number of features: {X_fs.shape[1]}")
print("Some selected features:", selected_features[:15])

# 8.3 Re-run CV with the reduced feature set
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

oof_pred_fs = np.zeros(len(X_fs))
test_pred_fs = np.zeros(len(X_test_fs))
fold_auc_scores_fs = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X_fs, y), start=1):
    print(f"\n===== [FS] Fold {fold}/{n_splits} =====")
    
    X_trn, X_val = X_fs[train_idx], X_fs[val_idx]
    y_trn, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    model_fs = xgb.XGBClassifier(
        n_estimators=2000,
        learning_rate=0.02,
        max_depth=4,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=2.0,
        reg_lambda=3.0,
        objective="binary:logistic",
        eval_metric="auc",
        random_state=42,
        n_jobs=-1
    )
    
    model_fs.fit(
        X_trn, y_trn,
        eval_set=[(X_trn, y_trn), (X_val, y_val)],
        verbose=100,
        early_stopping_rounds=200
    )
    
    val_proba = model_fs.predict_proba(X_val)[:, 1]
    oof_pred_fs[val_idx] = val_proba
    
    fold_auc = roc_auc_score(y_val, val_proba)
    fold_auc_scores_fs.append(fold_auc)
    print(f"[FS] Fold {fold} AUC: {fold_auc:.6f}")
    
    test_proba = model_fs.predict_proba(X_test_fs)[:, 1]
    test_pred_fs += test_proba / n_splits

# 8.4 Overall CV performance with feature selection
cv_auc_fs = roc_auc_score(y, oof_pred_fs)
print("\n===== [FS] Cross-validation summary =====")
print("Fold AUCs (FS):", [round(s, 6) for s in fold_auc_scores_fs])
print(f"Mean AUC (FS): {np.mean(fold_auc_scores_fs):.6f}  |  Std: {np.std(fold_auc_scores_fs):.6f}")
print(f"OOF CV AUC with feature selection: {cv_auc_fs:.6f}")
# Out:
# Original number of features: 27
# Selected number of features: 14
# Some selected features: ['age', 'physical_activity_minutes_per_week', 'diet_score', 'bmi', 'waist_to_hip_ratio', 'systolic_bp', 'heart_rate', 'hdl_cholesterol', 'ldl_cholesterol', 'triglycerides', 'family_history_diabetes', 'cardiovascular_history', 'bmi_cat', 'non_hdl']
#
# ===== [FS] Fold 1/5 =====
# [0]	validation_0-auc:0.67134	validation_1-auc:0.67229
# [100]	validation_0-auc:0.69723	validation_1-auc:0.69715
# [200]	validation_0-auc:0.70437	validation_1-auc:0.70376
# [300]	validation_0-auc:0.70920	validation_1-auc:0.70827
# [400]	validation_0-auc:0.71215	validation_1-auc:0.71100
# [500]	validation_0-auc:0.71505	validation_1-auc:0.71368
# [600]	validation_0-auc:0.71719	validation_1-auc:0.71560
# [700]	validation_0-auc:0.71932	validation_1-auc:0.71754
# [800]	validation_0-auc:0.72119	validation_1-auc:0.71922
# [900]	validation_0-auc:0.72264	validation_1-auc:0.72044
# [1000]	validation_0-auc:0.72391	validation_1-auc:0.72147
# [1100]	validation_0-auc:0.72480	validation_1-auc:0.72209
# [1200]	validation_0-auc:0.72566	validation_1-auc:0.72266
# [1300]	validation_0-auc:0.72644	validation_1-auc:0.72318
# [1400]	validation_0-auc:0.72717	validation_1-auc:0.72365
# [1500]	validation_0-auc:0.72783	validation_1-auc:0.72405
# [1600]	validation_0-auc:0.72845	validation_1-auc:0.72438
# [1700]	validation_0-auc:0.72898	validation_1-auc:0.72464
# [1800]	validation_0-auc:0.72948	validation_1-auc:0.72487
# [1900]	validation_0-auc:0.72999	validation_1-auc:0.72513
# [1999]	validation_0-auc:0.73045	validation_1-auc:0.72530
# [FS] Fold 1 AUC: 0.725299
#
# ===== [FS] Fold 2/5 =====
# [0]	validation_0-auc:0.67240	validation_1-auc:0.67006
# [100]	validation_0-auc:0.69739	validation_1-auc:0.69547
# [200]	validation_0-auc:0.70469	validation_1-auc:0.70261
# [300]	validation_0-auc:0.70885	validation_1-auc:0.70630
# [400]	validation_0-auc:0.71181	validation_1-auc:0.70886
# [500]	validation_0-auc:0.71505	validation_1-auc:0.71181
# [600]	validation_0-auc:0.71757	validation_1-auc:0.71403
# [700]	validation_0-auc:0.71944	validation_1-auc:0.71560
# [800]	validation_0-auc:0.72124	validation_1-auc:0.71709
# [900]	validation_0-auc:0.72272	validation_1-auc:0.71829
# [1000]	validation_0-auc:0.72406	validation_1-auc:0.71934
# [1100]	validation_0-auc:0.72503	validation_1-auc:0.72003
# [1200]	validation_0-auc:0.72600	validation_1-auc:0.72070
# [1300]	validation_0-auc:0.72689	validation_1-auc:0.72129
# [1400]	validation_0-auc:0.72759	validation_1-auc:0.72173
# [1500]	validation_0-auc:0.72826	validation_1-auc:0.72214
# [1600]	validation_0-auc:0.72883	validation_1-auc:0.72246
# [1700]	validation_0-auc:0.72940	validation_1-auc:0.72277
# [1800]	validation_0-auc:0.72991	validation_1-auc:0.72305
# [1900]	validation_0-auc:0.73039	validation_1-auc:0.72326
# [1999]	validation_0-auc:0.73092	validation_1-auc:0.72356
# [FS] Fold 2 AUC: 0.723562
#
# ===== [FS] Fold 3/5 =====
# [0]	validation_0-auc:0.67330	validation_1-auc:0.67300
# [100]	validation_0-auc:0.69753	validation_1-auc:0.69649
# [200]	validation_0-auc:0.70458	validation_1-auc:0.70279
# [300]	validation_0-auc:0.70944	validation_1-auc:0.70721
# [400]	validation_0-auc:0.71255	validation_1-auc:0.71001
# [500]	validation_0-auc:0.71525	validation_1-auc:0.71247
# [600]	validation_0-auc:0.71764	validation_1-auc:0.71460
# [700]	validation_0-auc:0.71971	validation_1-auc:0.71642
# [800]	validation_0-auc:0.72138	validation_1-auc:0.71786
# [900]	validation_0-auc:0.72275	validation_1-auc:0.71894
# [1000]	validation_0-auc:0.72386	validation_1-auc:0.71982
# [1100]	validation_0-auc:0.72481	validation_1-auc:0.72054
# [1200]	validation_0-auc:0.72578	validation_1-auc:0.72128
# [1300]	validation_0-auc:0.72661	validation_1-auc:0.72188
# [1400]	validation_0-auc:0.72729	validation_1-auc:0.72232
# [1500]	validation_0-auc:0.72796	validation_1-auc:0.72274
# [1600]	validation_0-auc:0.72856	validation_1-auc:0.72311
# [1700]	validation_0-auc:0.72909	validation_1-auc:0.72337
# [1800]	validation_0-auc:0.72959	validation_1-auc:0.72360
# [1900]	validation_0-auc:0.73011	validation_1-auc:0.72387
# [1999]	validation_0-auc:0.73061	validation_1-auc:0.72414
# [FS] Fold 3 AUC: 0.724136
#
# ===== [FS] Fold 4/5 =====
# [0]	validation_0-auc:0.67225	validation_1-auc:0.67133
# [100]	validation_0-auc:0.69771	validation_1-auc:0.69659
# [200]	validation_0-auc:0.70493	validation_1-auc:0.70393
# [300]	validation_0-auc:0.70960	validation_1-auc:0.70839
# [400]	validation_0-auc:0.71214	validation_1-auc:0.71075
# [500]	validation_0-auc:0.71470	validation_1-auc:0.71307
# [600]	validation_0-auc:0.71760	validation_1-auc:0.71576
# [700]	validation_0-auc:0.71957	validation_1-auc:0.71753
# [800]	validation_0-auc:0.72149	validation_1-auc:0.71923
# [900]	validation_0-auc:0.72285	validation_1-auc:0.72038
# [1000]	validation_0-auc:0.72402	validation_1-auc:0.72133
# [1100]	validation_0-auc:0.72492	validation_1-auc:0.72197
# [1200]	validation_0-auc:0.72581	validation_1-auc:0.72262
# [1300]	validation_0-auc:0.72672	validation_1-auc:0.72332
# [1400]	validation_0-auc:0.72746	validation_1-auc:0.72383
# [1500]	validation_0-auc:0.72811	validation_1-auc:0.72421
# [1600]	validation_0-auc:0.72873	validation_1-auc:0.72456
# [1700]	validation_0-auc:0.72924	validation_1-auc:0.72482
# [1800]	validation_0-auc:0.72976	validation_1-auc:0.72510
# [1900]	validation_0-auc:0.73032	validation_1-auc:0.72542
# [1999]	validation_0-auc:0.73079	validation_1-auc:0.72564
# [FS] Fold 4 AUC: 0.725645
#
# ===== [FS] Fold 5/5 =====
# [0]	validation_0-auc:0.67181	validation_1-auc:0.67233
# [100]	validation_0-auc:0.69720	validation_1-auc:0.69669
# [200]	validation_0-auc:0.70439	validation_1-auc:0.70369
# [300]	validation_0-auc:0.70875	validation_1-auc:0.70779
# [400]	validation_0-auc:0.71192	validation_1-auc:0.71063
# [500]	validation_0-auc:0.71499	validation_1-auc:0.71340
# [600]	validation_0-auc:0.71745	validation_1-auc:0.71553
# [700]	validation_0-auc:0.71927	validation_1-auc:0.71707
# [800]	validation_0-auc:0.72098	validation_1-auc:0.71851
# [900]	validation_0-auc:0.72244	validation_1-auc:0.71970
# [1000]	validation_0-auc:0.72363	validation_1-auc:0.72066
# [1100]	validation_0-auc:0.72457	validation_1-auc:0.72130
# [1200]	validation_0-auc:0.72544	validation_1-auc:0.72191
# [1300]	validation_0-auc:0.72621	validation_1-auc:0.72241
# [1400]	validation_0-auc:0.72698	validation_1-auc:0.72288
# [1500]	validation_0-auc:0.72763	validation_1-auc:0.72322
# [1600]	validation_0-auc:0.72823	validation_1-auc:0.72355
# [1700]	validation_0-auc:0.72879	validation_1-auc:0.72383
# [1800]	validation_0-auc:0.72929	validation_1-auc:0.72406
# [1900]	validation_0-auc:0.72980	validation_1-auc:0.72429
# [1999]	validation_0-auc:0.73031	validation_1-auc:0.72452
# [FS] Fold 5 AUC: 0.724524
#
# ===== [FS] Cross-validation summary =====
# Fold AUCs (FS): [0.725299, 0.723562, 0.724136, 0.725645, 0.724524]
# Mean AUC (FS): 0.724633  |  Std: 0.000758
# OOF CV AUC with feature selection: 0.724627

# %% [markdown]
# ## Probability Calibration

# %%
# =========================
# Part 9: Probability calibration (Isotonic Regression)
# =========================

from sklearn.isotonic import IsotonicRegression

# 9.1 Fit calibrator on OOF predictions vs true labels
calibrator = IsotonicRegression(out_of_bounds="clip")

calibrator.fit(oof_pred_fs, y)

# 9.2 Apply calibration to test predictions
test_pred_cal = calibrator.transform(test_pred_fs)

print("Before calibration:")
print(f"  Mean raw test prediction: {test_pred_fs.mean():.5f}")

print("After calibration:")
print(f"  Mean calibrated test prediction: {test_pred_cal.mean():.5f}")
# Out:
# Before calibration:
#   Mean raw test prediction: 0.60165
# After calibration:
#   Mean calibrated test prediction: 0.60063

# %%
# Optional: Save calibrated predictions as a new submission

submission_cal = submission.copy()
submission_cal[TARGET] = test_pred_cal

OUTPUT_PATH_CAL = "submission_xgb_fs_calibrated.csv"
submission_cal.to_csv(OUTPUT_PATH_CAL, index=False)

print(f"Calibrated submission file saved as: {OUTPUT_PATH_CAL}")
print(f"Mean calibrated prediction: {submission_cal[TARGET].mean():.5f}")
submission_cal.head()
# Out:
# Calibrated submission file saved as: submission_xgb_fs_calibrated.csv
# Mean calibrated prediction: 0.60063
#        id  diagnosed_diabetes
# 0  700000            0.484055
# 1  700001            0.712696
# 2  700002            0.765183
# 3  700003            0.399170
# 4  700004            0.914367
